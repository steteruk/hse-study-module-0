# %%
import pandas as pd
url_movies = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url_movies)

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(df, title = 'Report data set')
report.to_file('titanic_report.html')
